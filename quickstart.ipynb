# %% [markdown]
# # Set up dataset

# %% [markdown]
# ## Create data frame

# %%
import utils

with open('youtube_api_key.txt','r') as f:
    youtube_api_key = f.read()

df = utils.build_dataset(youtube_api_key)
# Out:
# ...
#     50 videos out of 54985
#     100 videos out of 54985
#     150 videos out of 54985
#     200 videos out of 54985
#     250 videos out of 54985
#     300 videos out of 54985
#     350 videos out of 54985
#     400 videos out of 54985
#     450 videos out of 54985
#     500 videos out of 54985
#     550 videos out of 54985
#     600 videos out of 54985
#     650 videos out of 54985
#     700 videos out of 54985
#     750 videos out of 54985
#     800 videos out of 54985
#     850 videos out of 54985
#     900 videos out of 54985
#     950 videos out of 54985
#     1000 videos out of 54985
#     1050 videos out of 54985
#     1100 videos out of 54985
#     1150 videos out of 54985
#     1200 videos out of 54985
#     1250 videos out of 54985
#     1300 videos out of 54985
#     1350 videos out of 54985
#     1400 videos out of 54985
#     1450 videos out of 54985
#     1500 videos out of 54985
#     1550 videos out of 54985
#     1600 videos out of 54985
# ...

# %% [markdown]
# ## Save data frame

# %%
import datetime

df.to_csv(
    'tournesol_scores_'
    +datetime.date.today().isoformat()
    +'.csv'
)

# %% [markdown]
# ## Load data frame

# %%
import pandas as pd

df = pd.read_csv('tournesol_scores_2025-04-10.csv')
